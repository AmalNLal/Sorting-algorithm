# %%
import matplotlib.pyplot as plt
import random 
import time
# %matplotlib notebook

# %%
x=[]
for i in range(10):
    x.append(random.randint(1,11))

    

length=len(x)-1

def quick(p,l,r,x):
    print(x)
    
    if p<r  and x[p]>x[r] :
        x[p],x[r]=x[r],x[p]
        quick(r,l,r,x)
        
    elif p>l and x[p] <x[l]:
        x[p],x[l]=x[l],x[p]
        quick(l,l,r,x)
        
    elif p < r  and (x[p]<x[r] or x[p]=x[r]):
        r=r-1
        quick(p,l,r,x)
       
    elif p>l  and (x[p]>x[l] or x[p]=x[l]) :
        l=l+1
        quick(p,l,r,x)
    
    elif r==l==p:
        n.append(p)
        a=r-1
        b=len(x)-1
                
        while r>-1 and r<len(x): 
            quick(0,0,a,x)
            quick(p,l,b,x)
       
    
quick(0,0,length,x)
# Out:
# [2, 8, 2, 8, 10, 11, 6, 10, 9, 2] [0] [0] [9]
# [2, 8, 2, 8, 10, 11, 6, 10, 9, 2] [0] [0] [9]
# [2, 8, 2, 8, 10, 11, 6, 10, 9, 2] [0] [0] [9]
# [2, 8, 2, 8, 10, 11, 6, 10, 9, 2] [0] [0] [9]
# [2, 8, 2, 8, 10, 11, 6, 10, 9, 2] [0] [0] [9]
# [2, 8, 2, 8, 10, 11, 6, 10, 9, 2] [0] [0] [9]
# [2, 8, 2, 8, 10, 11, 6, 10, 9, 2] [0] [0] [9]
# [2, 8, 2, 8, 10, 11, 6, 10, 9, 2] [0] [0] [9]
# [2, 8, 2, 8, 10, 11, 6, 10, 9, 2] [0] [0] [9]
# [2, 8, 2, 8, 10, 11, 6, 10, 9, 2] [0] [0] [9]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-7ff3cf0f4c57> in <module>
#      48
#      49
# ---> 50 quick(0,0,length,x,pivot,left,right,i)
#
# <ipython-input-3-7ff3cf0f4c57> in quick(p, l, r, x, pivot, left, right, i)
#      24     if p < r  and (x[p]<x[r] or x[p]==x[r]):
#      25         r=r-1
# ---> 26         quick(p,l,r,x,pivot,left,right,i)
#      27
# ...
